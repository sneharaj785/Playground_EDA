# %% [markdown]
# ##LOAD LIBRARIES

# %% [markdown]
# We are going to load neccersary libraries.Below are the libraries that are used in order to perform EDA (Exploratory data analysis)

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import seaborn as sns
#visualisation
import matplotlib.pyplot as plt
#visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# ##LOAD DATA

# %% [markdown]
# Here we are going to loading data

# %%
import pandas as pd
df=pd.read_csv("/content/Playground.csv")
print(df.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df
# Out:
#                           Slug  \
# 0       playground-series-s3e1
# 1       playground-series-s3e1
# 2       playground-series-s3e1
# 3       playground-series-s3e1
# 4       playground-series-s3e1
# ...                        ...
# 27261  playground-series-s3e25
# 27262  playground-series-s3e25
# 27263  playground-series-s3e25
# 27264  playground-series-s3e25
# 27265  playground-series-s3e25
#
#                                                    Title  \
# 0      Regression with a Tabular California Housing D...
# 1      Regression with a Tabular California Housing D...
# 2      Regression with a Tabular California Housing D...
# 3      Regression with a Tabular California Housing D...
# 4      Regression with a Tabular California Housing D...
# ...                                                  ...
# 27261            Regression with a Mohs Hardness Dataset
# 27262            Regression with a Mohs Hardness Dataset
# 27263            Regression with a Mohs Hardness Dataset
# ...

# %% [markdown]
# ##LOAD HEAD

# %% [markdown]
# here we are loading head

# %%
print(df. head(5))
# Out:
#                      Slug                                              Title  \
# 0  playground-series-s3e1  Regression with a Tabular California Housing D...
# 1  playground-series-s3e1  Regression with a Tabular California Housing D...
# 2  playground-series-s3e1  Regression with a Tabular California Housing D...
# 3  playground-series-s3e1  Regression with a Tabular California Housing D...
# 4  playground-series-s3e1  Regression with a Tabular California Housing D...
#
#                                   Subtitle  Episode  RankPrivate   TeamId  \
# 0  Playground Series - Season 3, Episode 1        1            1  9706700
# 1  Playground Series - Season 3, Episode 1        1            2  9697551
# 2  Playground Series - Season 3, Episode 1        1            3  9696540
# 3  Playground Series - Season 3, Episode 1        1            4  9704143
# 4  Playground Series - Season 3, Episode 1        1            5  9700304
#
# ...

# %% [markdown]
# ##LOAD TAIL

# %% [markdown]
# here we are loading tail

# %%
print(df.tail(5))
# Out:
#                           Slug                                    Title  \
# 27261  playground-series-s3e25  Regression with a Mohs Hardness Dataset
# 27262  playground-series-s3e25  Regression with a Mohs Hardness Dataset
# 27263  playground-series-s3e25  Regression with a Mohs Hardness Dataset
# 27264  playground-series-s3e25  Regression with a Mohs Hardness Dataset
# 27265  playground-series-s3e25  Regression with a Mohs Hardness Dataset
#
#                                        Subtitle  Episode  RankPrivate  \
# 27261  Playground Series - Season 3, Episode 25       25         1628
# 27262  Playground Series - Season 3, Episode 25       25         1629
# 27263  Playground Series - Season 3, Episode 25       25         1630
# 27264  Playground Series - Season 3, Episode 25       25         1631
# 27265  Playground Series - Season 3, Episode 25       25         1632
#
#          TeamId          TeamName LastSubmissionDatePrivate ScorePrivate  \
# ...

# %% [markdown]
# ##LOAD COLUMNS

# %% [markdown]
# here we are loading some column

# %%
import pandas as pd
df=pd.read_csv("/content/Playground.csv")
df.columns
# Out:
# Index(['Slug', 'Title', 'Subtitle', 'Episode', 'RankPrivate', 'TeamId',
#        'TeamName', 'LastSubmissionDatePrivate', 'ScorePrivate',
#        'SubmissionCount', 'TeamMemberUserNames', 'RankPublic',
#        'LastSubmissionDatePublic', 'ScorePublic'],
#       dtype='object')

# %% [markdown]
# ##Loading Datatypes

# %% [markdown]
# Here we are loading datatypes

# %%
import pandas as pd
df=pd.read_csv("/content/Playground.csv")
df.dtypes
# Out:
# Slug                         object
# Title                        object
# Subtitle                     object
# Episode                       int64
# RankPrivate                   int64
# TeamId                        int64
# TeamName                     object
# LastSubmissionDatePrivate    object
# ScorePrivate                 object
# SubmissionCount               int64
# TeamMemberUserNames          object
# RankPublic                    int64
# LastSubmissionDatePublic     object
# ScorePublic                  object
# dtype: object

# %% [markdown]
# ##Remove Duplicate Values

# %% [markdown]
# Remove duplicate values of a variable in pandas dataframe

# %%
rem_dup=df.drop_duplicates(['ScorePrivate','SubmissionCount'])
print(rem_dup)
# Out:
#                           Slug  \
# 0       playground-series-s3e1
# 1       playground-series-s3e1
# 2       playground-series-s3e1
# 3       playground-series-s3e1
# 4       playground-series-s3e1
# ...                        ...
# 27261  playground-series-s3e25
# 27262  playground-series-s3e25
# 27263  playground-series-s3e25
# 27264  playground-series-s3e25
# 27265  playground-series-s3e25
#
#                                                    Title  \
# 0      Regression with a Tabular California Housing D...
# 1      Regression with a Tabular California Housing D...
# 2      Regression with a Tabular California Housing D...
# 3      Regression with a Tabular California Housing D...
# 4      Regression with a Tabular California Housing D...
# ...                                                  ...
# 27261            Regression with a Mohs Hardness Dataset
# 27262            Regression with a Mohs Hardness Dataset
# 27263            Regression with a Mohs Hardness Dataset
# ...

# %% [markdown]
# ##Selection on row wise and column wise

# %% [markdown]
# Below are the data showing selection on row wise and column wise

# %%
df.iloc[:,[3,6,8,12]]
# Out:
#        Episode                 TeamName ScorePrivate LastSubmissionDatePublic
# 0            1                  Kirderf      0.55224      2023-01-09 13:54:39
# 1            1                 jcerpent      0.55274      2023-01-09 20:29:36
# 2            1                       NY      0.55292      2023-01-09 15:02:45
# 3            1  Tabular Tabular Tabular      0.55294      2023-01-07 16:13:18
# 4            1                    Satya      0.55297      2023-01-09 23:09:08
# ...        ...                      ...          ...                      ...
# 27261       25            Aniket Pathak      4.87354      2023-12-04 23:01:26
# 27262       25              KAJOL SINGH      4.88786      2023-12-04 11:12:17
# 27263       25               Berkay Sag      4.94919      2023-11-14 19:21:40
# 27264       25               SharmilaA1      5.99929      2023-12-04 06:25:17
# 27265       25         Hoang Manh Khiem    284.65472      2023-11-26 17:38:10
#
# [27266 rows x 4 columns]

# %%
df.isnull()
# Out:
#         Slug  Title  Subtitle  Episode  RankPrivate  TeamId  TeamName  \
# 0      False  False     False    False        False   False     False
# 1      False  False     False    False        False   False     False
# 2      False  False     False    False        False   False     False
# 3      False  False     False    False        False   False     False
# 4      False  False     False    False        False   False     False
# ...      ...    ...       ...      ...          ...     ...       ...
# 27261  False  False     False    False        False   False     False
# 27262  False  False     False    False        False   False     False
# 27263  False  False     False    False        False   False     False
# 27264  False  False     False    False        False   False     False
# 27265  False  False     False    False        False   False     False
#
#        LastSubmissionDatePrivate  ScorePrivate  SubmissionCount  \
# ...

# %% [markdown]
# ##FILTERING DATAFRAME

# %% [markdown]
# Here we get all rows having teamid greater than 350

# %%
df1=df[df["TeamId"]>350]
df1
# Out:
#                           Slug  \
# 0       playground-series-s3e1
# 1       playground-series-s3e1
# 2       playground-series-s3e1
# 3       playground-series-s3e1
# 4       playground-series-s3e1
# ...                        ...
# 27261  playground-series-s3e25
# 27262  playground-series-s3e25
# 27263  playground-series-s3e25
# 27264  playground-series-s3e25
# 27265  playground-series-s3e25
#
#                                                    Title  \
# 0      Regression with a Tabular California Housing D...
# 1      Regression with a Tabular California Housing D...
# 2      Regression with a Tabular California Housing D...
# 3      Regression with a Tabular California Housing D...
# 4      Regression with a Tabular California Housing D...
# ...                                                  ...
# 27261            Regression with a Mohs Hardness Dataset
# 27262            Regression with a Mohs Hardness Dataset
# 27263            Regression with a Mohs Hardness Dataset
# ...

# %% [markdown]
# Here we get all rows having rankprivate less than 30

# %%
df1=df[df["RankPrivate"]>30]
df1
# Out:
#                           Slug  \
# 30      playground-series-s3e1
# 31      playground-series-s3e1
# 32      playground-series-s3e1
# 33      playground-series-s3e1
# 34      playground-series-s3e1
# ...                        ...
# 27261  playground-series-s3e25
# 27262  playground-series-s3e25
# 27263  playground-series-s3e25
# 27264  playground-series-s3e25
# 27265  playground-series-s3e25
#
#                                                    Title  \
# 30     Regression with a Tabular California Housing D...
# 31     Regression with a Tabular California Housing D...
# 32     Regression with a Tabular California Housing D...
# 33     Regression with a Tabular California Housing D...
# 34     Regression with a Tabular California Housing D...
# ...                                                  ...
# 27261            Regression with a Mohs Hardness Dataset
# 27262            Regression with a Mohs Hardness Dataset
# 27263            Regression with a Mohs Hardness Dataset
# ...

# %% [markdown]
# ##==,&&,>

# %% [markdown]
# Here we get all rows having slug or teammemberusernames is equal to and teamid>300 of data frame

# %%
df.loc[(df['Slug']=='playground-series-s3e1')&(df['TeamMemberUserNames']=='bechirkarmeni')&(df['TeamId']>300)]
# Out:
#                       Slug                                              Title  \
# 30  playground-series-s3e1  Regression with a Tabular California Housing D...
#
#                                    Subtitle  Episode  RankPrivate   TeamId  \
# 30  Playground Series - Season 3, Episode 1        1           31  9705018
#
#           TeamName LastSubmissionDatePrivate ScorePrivate  SubmissionCount  \
# 30  bechir karmeni       2023-01-09 22:15:50      0.55475                4
#
#    TeamMemberUserNames  RankPublic LastSubmissionDatePublic ScorePublic
# 30       bechirkarmeni          26      2023-01-09 22:15:50     0.55261

# %% [markdown]
# ##LOAD GROUPBY

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.groupby
# Out:
# <bound method DataFrame.groupby of                           Slug  \
# 0       playground-series-s3e1
# 1       playground-series-s3e1
# 2       playground-series-s3e1
# 3       playground-series-s3e1
# 4       playground-series-s3e1
# ...                        ...
# 27261  playground-series-s3e25
# 27262  playground-series-s3e25
# 27263  playground-series-s3e25
# 27264  playground-series-s3e25
# 27265  playground-series-s3e25
#
#                                                    Title  \
# 0      Regression with a Tabular California Housing D...
# 1      Regression with a Tabular California Housing D...
# 2      Regression with a Tabular California Housing D...
# 3      Regression with a Tabular California Housing D...
# 4      Regression with a Tabular California Housing D...
# ...                                                  ...
# 27261            Regression with a Mohs Hardness Dataset
# 27262            Regression with a Mohs Hardness Dataset
# ...

# %% [markdown]
# ##FILTER THE DATA

# %%
df1=df[df["SubmissionCount"]>100]
df1
# Out:
#                           Slug  \
# 17118  playground-series-s3e19
# 18126  playground-series-s3e20
# 20274  playground-series-s3e21
# 20848  playground-series-s3e22
# 22182  playground-series-s3e23
# 23982  playground-series-s3e24
# 24108  playground-series-s3e24
#
#                                                    Title  \
# 17118                      Forecasting Mini-Course Sales
# 18126                    Predict CO2 Emissions in Rwanda
# 20274        Improve a Fixed Model the Data-Centric Way!
# 20848                  Predict Health Outcomes of Horses
# 22182  Binary Classification with a Software Defects ...
# 23982  Binary Prediction of Smoker Status using Bio-S...
# 24108  Binary Prediction of Smoker Status using Bio-S...
#
#                                        Subtitle  Episode  RankPrivate  \
# 17118  Playground Series - Season 3, Episode 19       19          215
# 18126  Playground Series - Season 3, Episode 20       20           49
# ...

# %% [markdown]
# ##Detecting Outliers

# %% [markdown]
# An outlier is a point or set of points that are different from other points

# %%
sns.boxplot(x=df['SubmissionCount'])
# Out:
# <Axes: xlabel='SubmissionCount'>

# %% [markdown]
# ##CORRELATION PLOT

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.corr()
# Out:
# <ipython-input-44-b1597a843d8d>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Episode  RankPrivate    TeamId  SubmissionCount  RankPublic
# Episode          1.000000     0.378814  0.987337        -0.001710    0.378814
# RankPrivate      0.378814     1.000000  0.389774        -0.318160    0.936699
# TeamId           0.987337     0.389774  1.000000        -0.016356    0.389828
# SubmissionCount -0.001710    -0.318160 -0.016356         1.000000   -0.374115
# RankPublic       0.378814     0.936699  0.389828        -0.374115    1.000000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_csv('/content/Playground.csv')
sns.heatmap(df.corr())
# Out:
# <ipython-input-45-a503d20a062f>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# ##LOAD MEAN

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.mean()
# Out:
# <ipython-input-46-1ed363677f1b>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Episode            1.510951e+01
# RankPrivate        6.193792e+02
# TeamId             1.047626e+07
# SubmissionCount    8.020282e+00
# RankPublic         6.193792e+02
# dtype: float64

# %% [markdown]
# ##LOAD MEDIAN

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.median()
# Out:
# <ipython-input-47-ca5f109b81aa>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Episode                  16.0
# RankPrivate             544.0
# TeamId             10495082.5
# SubmissionCount           5.0
# RankPublic              544.0
# dtype: float64

# %% [markdown]
# ##LOAD MODE

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.mode()
# Out:
#                           Slug  \
# 0      playground-series-s3e24
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 27261                      NaN
# 27262                      NaN
# 27263                      NaN
# 27264                      NaN
# 27265                      NaN
#
#                                                    Title  \
# 0      Binary Prediction of Smoker Status using Bio-S...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27261                                                NaN
# 27262                                                NaN
# 27263                                                NaN
# ...

# %% [markdown]
# ##STANDARD DEVIATION

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.std()
# Out:
# <ipython-input-49-e457380056f3>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Episode                 7.045078
# RankPrivate           434.813835
# TeamId             482367.031931
# SubmissionCount        10.066261
# RankPublic            434.813835
# dtype: float64

# %% [markdown]
# ##SUM OF NULL VALUES OF EACH COLUMN

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.isnull().sum()
# Out:
# Slug                          0
# Title                         0
# Subtitle                      0
# Episode                       0
# RankPrivate                   0
# TeamId                        0
# TeamName                      0
# LastSubmissionDatePrivate     0
# ScorePrivate                  0
# SubmissionCount               0
# TeamMemberUserNames          43
# RankPublic                    0
# LastSubmissionDatePublic      0
# ScorePublic                   0
# dtype: int64

# %% [markdown]
# ##SOME OF DUPLICATE OF DATA

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##CHECK FOR DUPLICATION

# %%
df.nunique()
# Out:
# Slug                            25
# Title                           25
# Subtitle                        25
# Episode                         25
# RankPrivate                   1909
# TeamId                       27266
# TeamName                     15374
# LastSubmissionDatePrivate    27234
# ScorePrivate                 19032
# SubmissionCount                 93
# TeamMemberUserNames          14953
# RankPublic                    1909
# LastSubmissionDatePublic     27234
# ScorePublic                  17882
# dtype: int64

# %% [markdown]
# ##CALCULATE THE PERCENTAGE OF MISSING VALUES IN EACH COLUMN

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
(df.isnull().sum()/(len(df)))*100
# Out:
# Slug                         0.000000
# Title                        0.000000
# Subtitle                     0.000000
# Episode                      0.000000
# RankPrivate                  0.000000
# TeamId                       0.000000
# TeamName                     0.000000
# LastSubmissionDatePrivate    0.000000
# ScorePrivate                 0.000000
# SubmissionCount              0.000000
# TeamMemberUserNames          0.157706
# RankPublic                   0.000000
# LastSubmissionDatePublic     0.000000
# ScorePublic                  0.000000
# dtype: float64

# %% [markdown]
# ##COUNT UNIQUE OF MAX COLUMN

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df['ScorePrivate'].value_counts()
# Out:
# 0.5          200
# 0.25         190
# 1.02648      166
# 0.79411       61
# 0.74545       54
#             ...
# 0.73596        1
# 0.73587        1
# 0.73575        1
# 0.73538        1
# 284.65472      1
# Name: ScorePrivate, Length: 19032, dtype: int64

# %% [markdown]
# ##LOAD SUM

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.sum()
# Out:
# <ipython-input-21-6fb9d85ac48f>:3: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()
# Slug                         playground-series-s3e1playground-series-s3e1pl...
# Title                        Regression with a Tabular California Housing D...
# Subtitle                     Playground Series - Season 3, Episode 1Playgro...
# Episode                                                                 411976
# RankPrivate                                                           16887994
# TeamId                                                            285645829250
# TeamName                     KirderfjcerpentNYTabular Tabular TabularSatyaC...
# LastSubmissionDatePrivate    2023-01-09 13:54:392023-01-09 20:29:362023-01-...
# ...

# %% [markdown]
# ##LOAD COUNT

# %%
import pandas as pd
df=pd.read_csv('/content/Playground.csv')
df.count()
# Out:
# Slug                         27266
# Title                        27266
# Subtitle                     27266
# Episode                      27266
# RankPrivate                  27266
# TeamId                       27266
# TeamName                     27266
# LastSubmissionDatePrivate    27266
# ScorePrivate                 27266
# SubmissionCount              27266
# TeamMemberUserNames          27223
# RankPublic                   27266
# LastSubmissionDatePublic     27266
# ScorePublic                  27266
# dtype: int64

# %% [markdown]
# ##LOAD COLUMNS

# %%
import pandas as pd
df=pd.read_csv("/content/Playground.csv")
df.columns
# Out:
# Index(['Slug', 'Title', 'Subtitle', 'Episode', 'RankPrivate', 'TeamId',
#        'TeamName', 'LastSubmissionDatePrivate', 'ScorePrivate',
#        'SubmissionCount', 'TeamMemberUserNames', 'RankPublic',
#        'LastSubmissionDatePublic', 'ScorePublic'],
#       dtype='object')

# %% [markdown]
# ##PIE CHART

# %% [markdown]
# A pie chart (or a circle chart) is a circular statistical graphic which is divided into slices to illustrate numerical proportion.

# %%
df.groupby(['Title']).sum().plot( kind='pie', y='TeamId',autopct='%1.0f%%')
# Out:
# <ipython-input-9-a979dad6b76a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Title']).sum().plot( kind='pie', y='TeamId',autopct='%1.0f%%')
# <Axes: ylabel='TeamId'>

# %%
sns.lineplot(x="TeamName", y="Episode", data=df)
# Out:
# <Axes: xlabel='TeamName', ylabel='Episode'>

# %% [markdown]
# ##BOXPLOT

# %% [markdown]
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum.You can create a box plot for any numerical column using a single line of code.
#
# [ ]

# %%
df[['TeamId']].boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['RankPublic'])
# Out:
# <Axes: xlabel='RankPublic'>

# %%
df[['RankPrivate']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ##DISTPLOT

# %% [markdown]
# A distplot plots a univariate distribution of observations.

# %%
plt.figure(figsize=(6,3.2),dpi=150)
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=8)
sns.distplot(df['TeamId'])
plt.show()

# %% [markdown]
# ##HISTPLOT

# %% [markdown]
# ###VISUALISE THE UNIQUE COUNT

# %% [markdown]
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within discrete bins.

# %%
sns.histplot(df['TeamId'],palette='hls')
plt.show()

# %%
sns.distplot(df['RankPrivate'], kde = False, color ='red', bins =5)
# Out:
# <Axes: xlabel='RankPrivate'>

# %% [markdown]
# ##SCATTERPLOT

# %% [markdown]
# Scatter plots are the graphs that present the relationship between two variables in a data-set.

# %%
import seaborn as sns
sns.scatterplot(x='SubmissionCount',y='RankPublic',data=df)
# Out:
# <Axes: xlabel='SubmissionCount', ylabel='RankPublic'>

# %%
sns.scatterplot(x='Episode',y='TeamId',data=df)
# Out:
# <Axes: xlabel='Episode', ylabel='TeamId'>

# %% [markdown]
# ##PAIRPLOT

# %% [markdown]
# A pair plot is a data visualization that plots pair-wise relationships between all the variables of a dataset.

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# ##COUNTPLOT

# %% [markdown]
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.

# %%
sns.countplot(x='TeamName',data=df)
plt.show()

# %%
sns.countplot(x='Subtitle',data=df)
plt.show()

# %% [markdown]
# ##HEATMAP

# %% [markdown]
# A heatmap is a graphical representation of data that uses a system of color coding to represent different values.

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only="TeamId"),cmap='Greens',annot=True)
# Out:
# <Axes: >

# %%
data=np.random.rand(10,10)
plt.imshow(data,cmap='hot')
plt.show()

# %% [markdown]
# ##LINEPLOT

# %% [markdown]
# A line plot is a type of plot in Seaborn that shows the relationship between two variables by connecting the data points with a straight line.

# %%
sns.lineplot(x="Title",y="Episode",data=df)
plt.show()

# %%
sns.lineplot(x="Subtitle", y="Episode",data=df)
plt.show()

# %%
sns.lineplot(x="Episode", y="RankPrivate", data=df)
plt.show()

# %% [markdown]
# ##VIOLINPLOT

# %% [markdown]
# A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. It is used to visualize the distribution of numerical data.

# %%
sns.violinplot(x="RankPrivate",y="TeamId",data=df,color='cyan')
# Out:
# <Axes: xlabel='RankPrivate', ylabel='TeamId'>
